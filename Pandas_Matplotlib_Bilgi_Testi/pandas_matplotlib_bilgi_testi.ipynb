# %% [markdown]
# <a href="https://colab.research.google.com/github/selimhatipoglu/softito_egitim/blob/main/Pandas_Matplotlib_Bilgi_Testi/pandas_matplotlib_bilgi_testi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# HazırlıkSoru 0: pandas'ı pd, numpy'ı np, matplotlib.pyplot'u plt takma adıyla içe aktarın.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---## Bölüm 1 — SeriesSoru 1.1: Bir kırtasiyedeki ürünlerin stok adetlerini tutan bir Series oluşturun: index = ['Kalem','Defter','Silgi','Cetvel'], değerler = [300, 150, 80, 45].Soru 1.2: 'Silgi' ürününün stok adedini index adıyla seçip yazdırın.Soru 1.3: Stoğu en az olan ürünü .idxmin() ile bulun.Soru 1.4: Tüm ürünlerin toplam stok adedini .sum() ile hesaplayın.

# %%
stok = pd.Series(
    [300, 150, 80, 45],
    index=["Kalem", "Defter", "Silgi", "Cetvel"]
)

stok
# Out:
# Kalem     300
# Defter    150
# Silgi      80
# Cetvel     45
# dtype: int64

# %%
stok["Silgi"]
# Out:
# np.int64(80)

# %%
stok.idxmin()
# Out:
# 'Cetvel'

# %%
stok.sum()
# Out:
# np.int64(575)

# %% [markdown]
# ---## Bölüm 2 — DataFrame OluşturmaSoru 2.1: Bir spor salonundaki üyeleri temsil eden, uye_adi, paket_turu (örn. Aylık, Yıllık) ve odenen_tutar sütunlarından oluşan, en az 5 satırlık bir DataFrame oluşturun.Soru 2.2: .shape ile kaç üye ve kaç bilgi sütunu olduğunu kontrol edin.Soru 2.3: .columns ile sütun isimlerini listeleyin.

# %%
df_uye = pd.DataFrame({
    "uye_adi": ["Ali", "Ayşe", "Mehmet", "Zeynep", "Can"],
    "paket_turu": ["Aylık", "Yıllık", "Aylık", "Yıllık", "Aylık"],
    "odenen_tutar": [1200, 9500, 1200, 9500, 1200]
})

df_uye
# Out:
#   uye_adi paket_turu  odenen_tutar
# 0     Ali      Aylık          1200
# 1    Ayşe     Yıllık          9500
# 2  Mehmet      Aylık          1200
# 3  Zeynep     Yıllık          9500
# 4     Can      Aylık          1200

# %%
df_uye.shape
# Out:
# (5, 3)

# %%
df_uye.columns
# Out:
# Index(['uye_adi', 'paket_turu', 'odenen_tutar'], dtype='object')

# %% [markdown]
# ---## Bölüm 3 — CSV/Excel Okuma (Kavramsal)Gerçek bir dosyanız olmasa da sözdizimini test edelim.Soru 3.1: "satislar.csv" adlı bir dosyayı okuyup df_csv değişkenine atayan kodu yazın (dosya olmadığı için hata verecektir, bu normaldir — sadece doğru sözdizimini yazın).Soru 3.2: "rapor.xlsx" adlı bir Excel dosyasını okuyup df_excel değişkenine atayan kodu yazın.

# %%
df_csv = pd.read_csv("satislar.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_643/3577746893.py in <cell line: 0>()
# ----> 1 df_csv = pd.read_csv("satislar.csv")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'satislar.csv'

# %%
df_excel = pd.read_excel("rapor.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_643/1562461366.py in <cell line: 0>()
# ----> 1 df_excel = pd.read_excel("rapor.xlsx")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rapor.xlsx'

# %% [markdown]
# --## Bölüm 4 — Veriyi İncelemeAşağıdaki hücreyi çalıştırarak bir e-ticaret sipariş verisi oluşturun:Soru 4.1: .head(3) ve .tail(2) ile ilk 3 ve son 2 siparişi görüntüleyin.Soru 4.2: .info() ile hangi sütunda eksik veri olduğunu tespit edin.Soru 4.3: .describe() ile kargo süresi, ürün adedi ve toplam tutarın istatistiklerini inceleyin.

# %%
df = pd.DataFrame({
    "siparis_no": [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    "kargo_suresi": [2, 5, 3, np.nan, 1, 4, 6],
    "urun_adedi": [1, 3, 2, 5, 1, 2, 4],
    "toplam_tutar": [150.0, 480.5, 220.0, 610.0, 90.0, 310.0, 720.0]
})

df
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar
# 0        1001           2.0           1         150.0
# 1        1002           5.0           3         480.5
# 2        1003           3.0           2         220.0
# 3        1004           NaN           5         610.0
# 4        1005           1.0           1          90.0
# 5        1006           4.0           2         310.0
# 6        1007           6.0           4         720.0

# %%
df.head(3)
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar
# 0        1001           2.0           1         150.0
# 1        1002           5.0           3         480.5
# 2        1003           3.0           2         220.0

# %%
df.tail(2)
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar
# 5        1006           4.0           2         310.0
# 6        1007           6.0           4         720.0

# %%
df.tail(2)
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar
# 5        1006           4.0           2         310.0
# 6        1007           6.0           4         720.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   siparis_no    7 non-null      int64
#  1   kargo_suresi  6 non-null      float64
#  2   urun_adedi    7 non-null      int64
#  3   toplam_tutar  7 non-null      float64
# dtypes: float64(2), int64(2)
# memory usage: 356.0 bytes

# %%
df[["kargo_suresi", "urun_adedi", "toplam_tutar"]].describe()

# %% [markdown]
# -## Bölüm 5 — Sütun ve Satır SeçmeYukarıdaki sipariş df'ini kullanarak:Soru 5.1: Sadece siparis_no ve toplam_tutar sütunlarını seçip yazdırın.Soru 5.2: .loc[] ile 0'dan 3'e kadar olan (0-3 dahil) satırları seçin.Soru 5.3: .iloc[] ile ilk 4 satırın son 2 sütununu seçin.

# %%
df[["siparis_no", "toplam_tutar"]]
# Out:
#    siparis_no  toplam_tutar
# 0        1001         150.0
# 1        1002         480.5
# 2        1003         220.0
# 3        1004         610.0
# 4        1005          90.0
# 5        1006         310.0
# 6        1007         720.0

# %%
df.loc[0:3]
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar
# 0        1001           2.0           1         150.0
# 1        1002           5.0           3         480.5
# 2        1003           3.0           2         220.0
# 3        1004           NaN           5         610.0

# %%
df.iloc[:4, -2:]
# Out:
#    urun_adedi  toplam_tutar
# 0           1         150.0
# 1           3         480.5
# 2           2         220.0
# 3           5         610.0

# %% [markdown]
# ---## Bölüm 6 — Filtreleme ve Yeni SütunSoru 6.1: Toplam tutarı 300 TL'nin üzerinde olan siparişleri filtreleyin.Soru 6.2: Ürün adedi 2'den fazla VE toplam tutar 200 TL'den fazla olan siparişleri bulun (& kullanın).Soru 6.3: birim_fiyat adında yeni bir sütun ekleyin; değeri toplam_tutar / urun_adedi olsun.Soru 6.4: apply ve lambda kullanarak kargo süresi 3 günden fazlaysa "Yavaş", değilse "Hızlı" yazan bir kargo_durumu sütunu oluşturun.

# %%
df[df["toplam_tutar"] > 300]
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar
# 1        1002           5.0           3         480.5
# 3        1004           NaN           5         610.0
# 5        1006           4.0           2         310.0
# 6        1007           6.0           4         720.0

# %%
df[(df["urun_adedi"] > 2) & (df["toplam_tutar"] > 200)]

# %%
df["birim_fiyat"] = df["toplam_tutar"] / df["urun_adedi"]

df
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar  birim_fiyat
# 0        1001           2.0           1         150.0   150.000000
# 1        1002           5.0           3         480.5   160.166667
# 2        1003           3.0           2         220.0   110.000000
# 3        1004           NaN           5         610.0   122.000000
# 4        1005           1.0           1          90.0    90.000000
# 5        1006           4.0           2         310.0   155.000000
# 6        1007           6.0           4         720.0   180.000000

# %%
df["kargo_durumu"] = df["kargo_suresi"].apply(
    lambda x: "Yavaş" if x > 3 else "Hızlı"
)

df
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar  birim_fiyat  \
# 0        1001           2.0           1         150.0   150.000000
# 1        1002           5.0           3         480.5   160.166667
# 2        1003           3.0           2         220.0   110.000000
# 3        1004           NaN           5         610.0   122.000000
# 4        1005           1.0           1          90.0    90.000000
# 5        1006           4.0           2         310.0   155.000000
# 6        1007           6.0           4         720.0   180.000000
#
#   kargo_durumu
# 0        Hızlı
# 1        Yavaş
# 2        Hızlı
# 3        Hızlı
# 4        Hızlı
# 5        Yavaş
# 6        Yavaş

# %% [markdown]
# ---## Bölüm 7 — SıralamaSoru 7.1: Siparişleri toplam_tutar sütununa göre büyükten küçüğe sıralayın.Soru 7.2: Siparişleri önce urun_adedi, sonra kargo_suresi sütununa göre (ikisi de küçükten büyüğe) sıralayın (bir listede iki sütun verin).

# %%
df.sort_values(by="toplam_tutar", ascending=False)
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar  birim_fiyat  \
# 6        1007           6.0           4         720.0   180.000000
# 3        1004           NaN           5         610.0   122.000000
# 1        1002           5.0           3         480.5   160.166667
# 5        1006           4.0           2         310.0   155.000000
# 2        1003           3.0           2         220.0   110.000000
# 0        1001           2.0           1         150.0   150.000000
# 4        1005           1.0           1          90.0    90.000000
#
#   kargo_durumu
# 6        Yavaş
# 3        Hızlı
# 1        Yavaş
# 5        Yavaş
# 2        Hızlı
# 0        Hızlı
# 4        Hızlı

# %%
df.sort_values(
    by=["urun_adedi", "kargo_suresi"],
    ascending=[True, True]
)
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar  birim_fiyat  \
# 4        1005           1.0           1          90.0    90.000000
# 0        1001           2.0           1         150.0   150.000000
# 2        1003           3.0           2         220.0   110.000000
# 5        1006           4.0           2         310.0   155.000000
# 1        1002           5.0           3         480.5   160.166667
# 6        1007           6.0           4         720.0   180.000000
# 3        1004           NaN           5         610.0   122.000000
#
#   kargo_durumu
# 4        Hızlı
# 0        Hızlı
# 2        Hızlı
# 5        Yavaş
# 1        Yavaş
# 6        Yavaş
# 3        Hızlı

# %% [markdown]
# ---## Bölüm 8 — Eksik Veri (NaN)Soru 8.1: kargo_suresi sütununda kaç eksik değer olduğunu bulun.Soru 8.2: Eksik kargo süresini sütunun medyanı ile doldurup df_dolu adlı yeni bir DataFrame oluşturun.Soru 8.3: Eksik değer içeren satırı silerek df_temiz adlı yeni bir DataFrame oluşturun ve satır sayısının değiştiğini .shape ile doğrulayın.

# %%
df["kargo_suresi"].isna().sum()
# Out:
# np.int64(1)

# %%
df_dolu = df.copy()

df_dolu["kargo_suresi"] = df_dolu["kargo_suresi"].fillna(
    df_dolu["kargo_suresi"].median()
)

df_dolu
# Out:
#    siparis_no  kargo_suresi  urun_adedi  toplam_tutar  birim_fiyat  \
# 0        1001           2.0           1         150.0   150.000000
# 1        1002           5.0           3         480.5   160.166667
# 2        1003           3.0           2         220.0   110.000000
# 3        1004           3.5           5         610.0   122.000000
# 4        1005           1.0           1          90.0    90.000000
# 5        1006           4.0           2         310.0   155.000000
# 6        1007           6.0           4         720.0   180.000000
#
#   kargo_durumu
# 0        Hızlı
# 1        Yavaş
# 2        Hızlı
# 3        Hızlı
# 4        Hızlı
# 5        Yavaş
# 6        Yavaş

# %%
df_temiz = df.dropna()

df_temiz.shape

# %% [markdown]
# -## Bölüm 9 — Merge (Tabloları Birleştirme)Aşağıdaki iki tabloyu kullanın:Soru 9.1: musteriler ve siparisler tablolarını inner join ile birleştirin — kaç müşterinin siparişi eşleşiyor?Soru 9.2: Aynı tabloları left join ile birleştirin — hiç siparişi olmayan müşteri(ler) sonuçta ne görünüyor?Soru 9.3: Aynı tabloları outer join ile birleştirip, hem eşleşmeyen müşterileri hem eşleşmeyen siparişleri gözlemleyin.

# %%
musteriler = pd.DataFrame({
    "musteri_id": [1, 2, 3, 4],
    "ad": ["Baran", "Ceylin", "Emre", "Fulya"]
})

siparisler = pd.DataFrame({
    "musteri_id": [1, 2, 5],
    "urun": ["Kulaklık", "Şarj Kablosu", "Powerbank"],
    "tutar": [450, 90, 320]
})

# %%
pd.merge(musteriler, siparisler, on="musteri_id", how="inner")
# Out:
#    musteri_id      ad          urun  tutar
# 0           1   Baran      Kulaklık    450
# 1           2  Ceylin  Şarj Kablosu     90

# %%
pd.merge(musteriler, siparisler, on="musteri_id", how="left")
# Out:
#    musteri_id      ad          urun  tutar
# 0           1   Baran      Kulaklık  450.0
# 1           2  Ceylin  Şarj Kablosu   90.0
# 2           3    Emre           NaN    NaN
# 3           4   Fulya           NaN    NaN

# %%
pd.merge(musteriler, siparisler, on="musteri_id", how="outer")
# Out:
#    musteri_id      ad          urun  tutar
# 0           1   Baran      Kulaklık  450.0
# 1           2  Ceylin  Şarj Kablosu   90.0
# 2           3    Emre           NaN    NaN
# 3           4   Fulya           NaN    NaN
# 4           5     NaN     Powerbank  320.0

# %% [markdown]
# ---## Bölüm 10 — ConcatSoru 10.1: hafta1 = pd.DataFrame({"gun":["Pzt","Sal"], "adet":[20,35]}) ve hafta2 = pd.DataFrame({"gun":["Çar","Per"], "adet":[28,40]}) tablolarını ignore_index=True ile alt alta birleştirin.Soru 10.2: gelir = pd.DataFrame({"toplam_gelir":[1000,1750]}) tablosunu, hafta1 tablosuyla axis=1 kullanarak yan yana birleştirin.

# %%
hafta1 = pd.DataFrame({
    "gun": ["Pzt", "Sal"],
    "adet": [20, 35]
})

hafta2 = pd.DataFrame({
    "gun": ["Çar", "Per"],
    "adet": [28, 40]
})

# %%
pd.concat([hafta1, hafta2], ignore_index=True)
# Out:
#    gun  adet
# 0  Pzt    20
# 1  Sal    35
# 2  Çar    28
# 3  Per    40

# %%
gelir = pd.DataFrame({
    "toplam_gelir": [1000, 1750]
})

# %%
pd.concat([hafta1, gelir], axis=1)
# Out:
#    gun  adet  toplam_gelir
# 0  Pzt    20          1000
# 1  Sal    35          1750

# %% [markdown]
# ---## Bölüm 11 — GroupByAşağıdaki veriyi kullanın:Soru 11.1: Şubeye göre toplam satışı bulun.Soru 11.2: Şubeye göre ortalama satışı bulun.Soru 11.3: .agg(["sum","mean","count"]) kullanarak şube başına üç istatistiği aynı anda hesaplayın.

# %%
df_calisan = pd.DataFrame({
    "sube": ["Kadıköy", "Beşiktaş", "Kadıköy", "Şişli", "Beşiktaş"],
    "ad": ["Baran", "Ceylin", "Emre", "Fulya", "Gökhan"],
    "satis": [12000, 18500, 9500, 21000, 16000]
})

# %%
df_calisan.groupby("sube")["satis"].sum()
# Out:
# sube
# Beşiktaş    34500
# Kadıköy     21500
# Şişli       21000
# Name: satis, dtype: int64

# %%
df_calisan.groupby("sube")["satis"].mean()
# Out:
# sube
# Beşiktaş    17250.0
# Kadıköy     10750.0
# Şişli       21000.0
# Name: satis, dtype: float64

# %%
df_calisan.groupby("sube")["satis"].agg(["sum", "mean", "count"])
# Out:
#             sum     mean  count
# sube
# Beşiktaş  34500  17250.0      2
# Kadıköy   21500  10750.0      2
# Şişli     21000  21000.0      1

# %% [markdown]
# -## Bölüm 12 — Pivot TableAşağıdaki veriyi kullanın:

# %% [markdown]
# **Soru 12.1:** `index="sehir"`, `columns="kategori"`, `values="satis"` ile bir pivot tablo oluşturun.**Soru 12.2:** Aynı pivot tabloyu `aggfunc="sum"` ve `fill_value=0` parametreleriyle oluşturup eksik hücrelerin nasıl doldurulduğunu gözlemleyin.

# %%
df_satis = pd.DataFrame({
    "sehir": ["Bursa", "Adana", "Antalya", "Bursa", "Adana"],
    "kategori": ["Elektronik", "Giyim", "Elektronik", "Giyim", "Elektronik"],
    "satis": [5000, 3200, 4100, 2800, 3900]
})

# %%
df_satis.pivot_table(
    index="sehir",
    columns="kategori",
    values="satis"
)
# Out:
# kategori  Elektronik   Giyim
# sehir
# Adana         3900.0  3200.0
# Antalya       4100.0     NaN
# Bursa         5000.0  2800.0

# %%
df_satis.pivot_table(
    index="sehir",
    columns="kategori",
    values="satis",
    aggfunc="sum",
    fill_value=0
)
# Out:
# kategori  Elektronik  Giyim
# sehir
# Adana           3900   3200
# Antalya         4100      0
# Bursa           5000   2800

# %% [markdown]
# ---## Bölüm 13 — Apply ile String İşlemleri**Soru 13.1:** `df_kullanici = pd.DataFrame({"kullanici_adi": ["baran23", "CEYLIN_K", "emre.y"]})` oluşturun.**Soru 13.2:** `apply(str.lower)` kullanarak tüm kullanıcı adlarını küçük harfe çeviren bir `kullanici_adi_kucuk` sütunu ekleyin.**Soru 13.3:** `apply` ve `lambda` ile kullanıcı adının kaç karakter olduğunu gösteren bir `karakter_sayisi` sütunu ekleyin.

# %%
# Soru 13.1
df_kullanici = pd.DataFrame({
    "kullanici_adi": ["baran23", "CEYLIN_K", "emre.y"]
})

# Soru 13.2
df_kullanici["kullanici_adi_kucuk"] = df_kullanici["kullanici_adi"].apply(str.lower)

# Soru 13.3
df_kullanici["karakter_sayisi"] = df_kullanici["kullanici_adi"].apply(lambda x: len(x))

display(df_kullanici)
# Out:
#   kullanici_adi kullanici_adi_kucuk  karakter_sayisi
# 0       baran23             baran23                7
# 1      CEYLIN_K            ceylin_k                8
# 2        emre.y              emre.y                6

# %% [markdown]
# ---## Bölüm 14 — Veri Tipi Dönüşümü (astype)Soru 14.1: df_urun = pd.DataFrame({"urun_id":["10","11","12"], "agirlik_kg":["1.5","0.75","3.2"]}) oluşturun.Soru 14.2: .info() ile sütunların object (metin) tipinde olduğunu doğrulayın.Soru 14.3: urun_id sütununu int, agirlik_kg sütununu float tipine dönüştürüp tekrar .info() ile kontrol edin.

# %%
# Soru 14.1
df_urun = pd.DataFrame({
    "urun_id": ["10", "11", "12"],
    "agirlik_kg": ["1.5", "0.75", "3.2"]
})

display(df_urun)
# Out:
#   urun_id agirlik_kg
# 0      10        1.5
# 1      11       0.75
# 2      12        3.2

# %%
# Soru 14.2
df_urun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   urun_id     3 non-null      object
#  1   agirlik_kg  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes

# %%
# Soru 14.3
df_urun["urun_id"] = df_urun["urun_id"].astype(int)

df_urun["agirlik_kg"] = df_urun["agirlik_kg"].astype(float)

df_urun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   urun_id     3 non-null      int64
#  1   agirlik_kg  3 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 180.0 bytes

# %% [markdown]
# Soru 15.1: gelir değerlerini kind="line" ile, üzerinde nokta işaretleri (marker="o") olacak şekilde çizgi grafikle çizin; başlık ve eksen etiketleri ekleyin.Soru 15.2: gelir değerlerini çeyreklere göre kind="bar" ile bar grafikle çizin (renk seçiminiz size ait).Soru 15.3: gelir sütununu çeyreklerin payını gösterecek şekilde kind="pie" ile pasta grafikle çizin (autopct="%1.1f%%" kullanın).Soru 15.4: gelir ve gider sütunlarını kind="scatter" ile scatter grafikte karşılaştırın (x ekseni gelir, y ekseni gider olsun) ve grafiğin ne anlattığını bir cümleyle yorumlayın.

# %%
df_gelir = pd.DataFrame({
    "ceyrek": ["Ç1", "Ç2", "Ç3", "Ç4"],
    "gelir": [42000, 55000, 48000, 61000],
    "gider": [30000, 38000, 33000, 40000]
})

display(df_gelir)
# Out:
#   ceyrek  gelir  gider
# 0     Ç1  42000  30000
# 1     Ç2  55000  38000
# 2     Ç3  48000  33000
# 3     Ç4  61000  40000

# %%
df_gelir.plot(
    x="ceyrek",
    y="gelir",
    kind="line",
    marker="o"
)

plt.title("Çeyreklere Göre Gelir")
plt.xlabel("Çeyrek")
plt.ylabel("Gelir")
plt.show()

# %%
df_gelir.plot(
    x="ceyrek",
    y="gelir",
    kind="line",
    marker="o"
)

plt.title("Çeyreklere Göre Gelir")
plt.xlabel("Çeyrek")
plt.ylabel("Gelir")
plt.show()

# %%
df_gelir.plot(
    y="gelir",
    kind="pie",
    labels=df_gelir["ceyrek"],
    autopct="%1.1f%%"
)

plt.title("Çeyreklerin Toplam Gelir İçindeki Payı")
plt.ylabel("")
plt.show()

# %%
df_gelir.plot(
    x="gelir",
    y="gider",
    kind="scatter"
)

plt.title("Gelir ve Gider İlişkisi")
plt.xlabel("Gelir")
plt.ylabel("Gider")
plt.show()

# %% [markdown]
# ---## Bonus — Kapsamlı UygulamaBir online kursun satış verisini simüle edin:1. kurs_adi, kategori (örn. Yazılım, Tasarım, Pazarlama) ve satis_adedi sütunlarından oluşan, en az 8 satırlık bir DataFrame oluşturun.2. Kategoriye göre toplam satış adedini groupby ile bulun.3. En çok satan 3 kursu .sort_values() ile bulun.4. Kategori bazında toplam satışı gösteren bir bar grafik çizin.5. apply ile satış adedi 50 üzeri olanlara "Popüler", altındakilere "Standart" yazan yeni bir sütun ekleyin.

# %%
df_kurs = pd.DataFrame({
    "kurs_adi": [
        "Python Temelleri",
        "Java ile Programlama",
        "Web Geliştirme",
        "Photoshop",
        "UI UX Tasarım",
        "Dijital Pazarlama",
        "SEO Eğitimi",
        "Sosyal Medya Pazarlama"
    ],

    "kategori": [
        "Yazılım",
        "Yazılım",
        "Yazılım",
        "Tasarım",
        "Tasarım",
        "Pazarlama",
        "Pazarlama",
        "Pazarlama"
    ],

    "satis_adedi": [
        85,
        72,
        60,
        45,
        55,
        68,
        40,
        52
    ]
})

display(df_kurs)
# Out:
#                  kurs_adi   kategori  satis_adedi
# 0        Python Temelleri    Yazılım           85
# 1    Java ile Programlama    Yazılım           72
# 2          Web Geliştirme    Yazılım           60
# 3               Photoshop    Tasarım           45
# 4           UI UX Tasarım    Tasarım           55
# 5       Dijital Pazarlama  Pazarlama           68
# 6             SEO Eğitimi  Pazarlama           40
# 7  Sosyal Medya Pazarlama  Pazarlama           52

# %%
kategori_satis = df_kurs.groupby("kategori")["satis_adedi"].sum()

display(kategori_satis)
# Out:
# kategori
# Pazarlama    160
# Tasarım      100
# Yazılım      217
# Name: satis_adedi, dtype: int64

# %%
en_cok_satan = df_kurs.sort_values(
    by="satis_adedi",
    ascending=False
).head(3)

display(en_cok_satan)
# Out:
#                kurs_adi   kategori  satis_adedi
# 0      Python Temelleri    Yazılım           85
# 1  Java ile Programlama    Yazılım           72
# 5     Dijital Pazarlama  Pazarlama           68

# %%
df_kurs.sort_values("satis_adedi", ascending=False).head(3)
# Out:
#                kurs_adi   kategori  satis_adedi
# 0      Python Temelleri    Yazılım           85
# 1  Java ile Programlama    Yazılım           72
# 5     Dijital Pazarlama  Pazarlama           68

# %%
kategori_satis.plot(
    kind="bar"
)

plt.title("Kategori Bazında Toplam Satış")
plt.xlabel("Kategori")
plt.ylabel("Toplam Satış Adedi")
plt.show()

# %%
df_kurs["durum"] = df_kurs["satis_adedi"].apply(
    lambda x: "Popüler" if x > 50 else "Standart"
)

display(df_kurs)
# Out:
#                  kurs_adi   kategori  satis_adedi     durum
# 0        Python Temelleri    Yazılım           85   Popüler
# 1    Java ile Programlama    Yazılım           72   Popüler
# 2          Web Geliştirme    Yazılım           60   Popüler
# 3               Photoshop    Tasarım           45  Standart
# 4           UI UX Tasarım    Tasarım           55   Popüler
# 5       Dijital Pazarlama  Pazarlama           68   Popüler
# 6             SEO Eğitimi  Pazarlama           40  Standart
# 7  Sosyal Medya Pazarlama  Pazarlama           52   Popüler
